# %%
import pandas as pd
import numpy as np
import sys

# %%
runs = [1,2,3,4,11,12,13,14,15]

# %%
# df_final_data = pd.read_csv('results/new_results_3/SE/final_data_100.csv')
run = str(runs[0])
df_results_high = pd.read_csv('results/final_results/TOL/results_' + run + '0.csv')
df_results_med = pd.read_csv('results/final_results/TOL/results_' + run + '1.csv')
df_results_low = pd.read_csv('results/final_results/TOL/results_' + run + '2.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [96], in <cell line: 3>()
#       1 # df_final_data = pd.read_csv('results/new_results_3/SE/final_data_100.csv')
#       2 run = str(runs[0])
# ----> 3 df_results_high = pd.read_csv('results/final_results/TOL/results_' + run + '0.csv')
#       4 df_results_med = pd.read_csv('results/final_results/TOL/results_' + run + '1.csv')
#       5 df_results_low = pd.read_csv('results/final_results/TOL/results_' + run + '2.csv')
#
# File ~/venv/new_env/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# ...

# %%
import pylab as plt
attr = 'network_polarization'
exp = [df_results_high[attr], df_results_med[attr], df_results_low[attr]]#, df_results_none[attr]]
# exp = [agent_polIncl['2']]
fig, ax = plt.subplots()
for i, e in enumerate(exp):
    temp = e
    plt.plot(range(len(temp)), temp)
# ax.legend()
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# df_final_data = pd.read_csv('results/new_results_3/SE/final_data_100.csv')
run = str(1)
df_results_high = pd.read_csv('results/new_results_2/SE/results_' + run + '0.csv')
df_results_med = pd.read_csv('results/new_results_2/SE/results_' + run + '1.csv')
df_results_low = pd.read_csv('results/new_results_2/SE/results_' + run + '2.csv')

# %%
import pylab as plt
attr = 'network_polarization'
exp = [df_results_high[attr], df_results_med[attr], df_results_low[attr]]#, df_results_none[attr]]
# exp = [agent_polIncl['2']]
fig, ax = plt.subplots()
for i, e in enumerate(exp):
    temp = e
    plt.plot(range(len(temp)), temp)
# ax.legend()
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# df_final_data = pd.read_csv('results/new_results_3/SE/final_data_100.csv')
run = str(1)
df_results_low = pd.read_csv('results/new_results/SE/results_' + run + '3.csv')
df_results_med = pd.read_csv('results/new_results/SE/results_' + run + '2.csv')
df_results_high = pd.read_csv('results/new_results/SE/results_' + run + '1.csv')
df_results_none = pd.read_csv('results/new_results/SE/results_' + run + '0.csv')

# %%
df_results_none.columns
# Out:
# Index(['Unnamed: 0', 'party_mentioned', 'post_stance', 'author_id',
#        'num_of_agents_received', 'num_of_agents_not_received',
#        'num_of_spreader_agents', 'num_of_disinterested_agents',
#        'network_polarization', 'network_homophily', 'network_polarity',
#        'user_satisfaction'],
#       dtype='object')

# %%
import pylab as plt
attr = 'network_polarization'
exp = [df_results_high[attr], df_results_med[attr], df_results_low[attr], df_results_none[attr]]
# exp = [agent_polIncl['2']]
fig, ax = plt.subplots()
for i, e in enumerate(exp):
    temp = e
    plt.plot(range(len(temp)), temp)
# ax.legend()
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# #### Blue = High
# #### Yellow = Med
# #### Green = Low
# #### Red = None
